# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /opt/homebrew/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.18 in /opt/homebrew/lib/python3.10/site-packages (from statsmodels) (1.23.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /opt/homebrew/lib/python3.10/site-packages (from statsmodels) (1.10.0)
# Requirement already satisfied: pandas>=1.0 in /opt/homebrew/lib/python3.10/site-packages (from statsmodels) (1.5.1)
# Requirement already satisfied: patsy>=0.5.2 in /opt/homebrew/lib/python3.10/site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /Users/delinaivanova/Library/Python/3.10/lib/python/site-packages (from statsmodels) (22.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/delinaivanova/Library/Python/3.10/lib/python/site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas>=1.0->statsmodels) (2022.6)
# Requirement already satisfied: six in /Users/delinaivanova/Library/Python/3.10/lib/python/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.10/site-packages (1.1.3)
# Requirement already satisfied: numpy>=1.17.3 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn) (1.23.3)
# Requirement already satisfied: scipy>=1.3.2 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: joblib>=1.0.0 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split

# %%
bikes = pd.read_csv('https://raw.githubusercontent.com/delinai/schulich_ds1/main/Datasets/bikes_sharing.csv')

# %%
bikes.head()
# Out:
#               datetime  season  holiday  ...  casual  registered  count
# 0  2011-01-01 00:00:00       1        0  ...       3          13     16
# 1  2011-01-01 01:00:00       1        0  ...       8          32     40
# 2  2011-01-01 02:00:00       1        0  ...       5          27     32
# 3  2011-01-01 03:00:00       1        0  ...       3          10     13
# 4  2011-01-01 04:00:00       1        0  ...       0           1      1
#
# [5 rows x 12 columns]

# %%
bikes.describe()
# Out:
#              season       holiday  ...    registered         count
# count  10886.000000  10886.000000  ...  10886.000000  10886.000000
# mean       2.506614      0.028569  ...    155.552177    191.574132
# std        1.116174      0.166599  ...    151.039033    181.144454
# min        1.000000      0.000000  ...      0.000000      1.000000
# 25%        2.000000      0.000000  ...     36.000000     42.000000
# 50%        3.000000      0.000000  ...    118.000000    145.000000
# 75%        4.000000      0.000000  ...    222.000000    284.000000
# max        4.000000      1.000000  ...    886.000000    977.000000
#
# [8 rows x 11 columns]

# %%
# feature engineering
# create daily version of data set
# convert the datetime column into a datetime data type
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
# with the pd.to_datetime() function we can make the change
bikes['datetime'] = pd.to_datetime(bikes['datetime'])

# %%
bikes.head()
# Out:
#              datetime  season  holiday  ...  casual  registered  count
# 0 2011-01-01 00:00:00       1        0  ...       3          13     16
# 1 2011-01-01 01:00:00       1        0  ...       8          32     40
# 2 2011-01-01 02:00:00       1        0  ...       5          27     32
# 3 2011-01-01 03:00:00       1        0  ...       3          10     13
# 4 2011-01-01 04:00:00       1        0  ...       0           1      1
#
# [5 rows x 12 columns]

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 1020.7 KB

# %%
# set the datetime as an index
bikes_daily = bikes.set_index('datetime')

# %%
bikes_daily = bikes_daily.resample('D').aggregate({'season':'max', 'holiday':'max','workingday':'max', 'weather':'max',\
                                                   'temp':'mean', 'atemp':'mean', 'humidity':'mean', 'windspeed':'mean',\
                                                    'casual':'sum', 'registered':'sum', 'count':'sum'})

# %%
bikes_daily
# Out:
#             season  holiday  workingday  ...  casual  registered  count
# datetime                                 ...
# 2011-01-01     1.0      0.0         0.0  ...     331         654    985
# 2011-01-02     1.0      0.0         0.0  ...     131         670    801
# 2011-01-03     1.0      0.0         1.0  ...     120        1229   1349
# 2011-01-04     1.0      0.0         1.0  ...     108        1454   1562
# 2011-01-05     1.0      0.0         1.0  ...      82        1518   1600
# ...            ...      ...         ...  ...     ...         ...    ...
# 2012-12-15     4.0      0.0         0.0  ...     767        4280   5047
# 2012-12-16     4.0      0.0         0.0  ...     538        3248   3786
# 2012-12-17     4.0      0.0         1.0  ...     212        4373   4585
# 2012-12-18     4.0      0.0         1.0  ...     433        5124   5557
# 2012-12-19     4.0      0.0         1.0  ...     333        4934   5267
#
# [719 rows x 11 columns]

# %%
bikes.iloc[:24].sum()
# Out:
# /var/folders/sf/vcdknkwn1j95s24kv8fbylx80000gn/T/ipykernel_70346/1945853085.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   bikes.iloc[:24].sum()
# season          24.0000
# holiday          0.0000
# workingday       0.0000
# weather         38.0000
# temp           338.6600
# atemp          436.3500
# humidity      1934.0000
# windspeed      257.9969
# casual         331.0000
# registered     654.0000
# count          985.0000
# dtype: float64

# %%
# isolate the hour of the day to assess time of day
bikes['hour'] = bikes['datetime'].apply(lambda x: x.hour)

# %%
bikes.head()
# Out:
#              datetime  season  holiday  ...  registered  count  hour
# 0 2011-01-01 00:00:00       1        0  ...          13     16     0
# 1 2011-01-01 01:00:00       1        0  ...          32     40     1
# 2 2011-01-01 02:00:00       1        0  ...          27     32     2
# 3 2011-01-01 03:00:00       1        0  ...          10     13     3
# 4 2011-01-01 04:00:00       1        0  ...           1      1     4
#
# [5 rows x 13 columns]

# %%
def time_of_day(x):
    if x >= 6 and x <= 9:
        return 'morning_commute'
    elif x > 9 and x <= 15:
        return 'midday'
    elif x > 15 and x <= 19:
        return 'evening_commute'
    else:
        return 'afterhours'

# %%
bikes['time_of_day'] = bikes['hour'].apply(time_of_day)

# %%
bikes.head()
# Out:
#              datetime  season  holiday  ...  count  hour      time_of_day
# 0 2011-01-01 00:00:00       1        0  ...     16     0       afterhours
# 1 2011-01-01 01:00:00       1        0  ...     40     1       afterhours
# 2 2011-01-01 02:00:00       1        0  ...     32     2       afterhours
# 3 2011-01-01 03:00:00       1        0  ...     13     3       afterhours
# 4 2011-01-01 04:00:00       1        0  ...      1     4  evening_commute
#
# [5 rows x 14 columns]

# %%
# return the weekday > day 0 = Monday
bikes['weekday'] = bikes['datetime'].apply(lambda x: x.weekday())

# %%
bikes.head()
# Out:
#              datetime  season  holiday  ...  hour      time_of_day  weekday
# 0 2011-01-01 00:00:00       1        0  ...     0       afterhours        5
# 1 2011-01-01 01:00:00       1        0  ...     1       afterhours        5
# 2 2011-01-01 02:00:00       1        0  ...     2       afterhours        5
# 3 2011-01-01 03:00:00       1        0  ...     3       afterhours        5
# 4 2011-01-01 04:00:00       1        0  ...     4  evening_commute        5
#
# [5 rows x 15 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# evaluate weekday vs number of casual or registered or total rentals
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (10,5), sharey=True)
sns.boxplot(x='weekday', y='casual', data=bikes, ax=ax1, palette='tab10')
sns.boxplot(x='weekday', y='registered', data=bikes, ax=ax2, palette='tab10')
sns.boxplot(x='weekday', y='count', data=bikes, ax=ax3, palette='tab10')
# Out:
# <AxesSubplot: xlabel='weekday', ylabel='count'>

# %%
# evaluate time_of_day vs number of casual or registered or total rentals
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (10,5), sharey=True)
sns.boxplot(x='time_of_day', y='casual', data=bikes, ax=ax1, palette='tab10')
sns.boxplot(x='time_of_day', y='registered', data=bikes, ax=ax2, palette='tab10')
sns.boxplot(x='time_of_day', y='count', data=bikes, ax=ax3, palette='tab10')

ax2.set_ylabel('registered')
ax3.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
bikes[bikes['time_of_day']=='evening_commute']['casual'].describe()
# Out:
# count    1824.000000
# mean       65.248904
# std        57.820172
# min         0.000000
# 25%        19.000000
# 50%        54.000000
# 75%        90.250000
# max       367.000000
# Name: casual, dtype: float64

# %%
# evaluate weekday & time_of_day vs number of casual or registered or total rentals
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (25,10), sharey=True)
sns.boxplot(x='weekday', y='casual', hue='time_of_day',data=bikes, ax=ax1, palette='tab10')
sns.boxplot(x='weekday', y='registered', hue='time_of_day',data=bikes, ax=ax2, palette='tab10')
sns.boxplot(x='weekday', y='count', hue='time_of_day',data=bikes, ax=ax3, palette='tab10')
# Out:
# <AxesSubplot: xlabel='weekday', ylabel='count'>

# %%
# lets look at Temperature vs. Rental Counts, add Weekday as a categorical element
# evaluate weekday & time_of_day vs number of casual or registered or total rentals
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (25,10), sharey=False)
sns.scatterplot(x='temp', y='casual', hue='weekday',data=bikes, ax=ax1, palette='tab10')
sns.scatterplot(x='temp', y='registered', hue='weekday', data=bikes, ax=ax2, palette='tab10')
sns.scatterplot(x='temp', y='count', hue='weekday', data=bikes, ax=ax3, palette='tab10')
# Out:
# <AxesSubplot: xlabel='temp', ylabel='count'>

# %%
bikes.head()
# Out:
#              datetime  season  holiday  ...  hour  time_of_day  weekday
# 0 2011-01-01 00:00:00       1        0  ...     0   afterhours        5
# 1 2011-01-01 01:00:00       1        0  ...     1   afterhours        5
# 2 2011-01-01 02:00:00       1        0  ...     2   afterhours        5
# 3 2011-01-01 03:00:00       1        0  ...     3   afterhours        5
# 4 2011-01-01 04:00:00       1        0  ...     4   afterhours        5
#
# [5 rows x 15 columns]

# %%
# temp, weekday, time_of_day
# for categoricals, they need to be converted into dummy variables
# get_dummies()

model_data = pd.get_dummies(data = bikes[['casual','temp','weekday','time_of_day']], columns=['weekday','time_of_day'], dtype=int)

# %%
model_data
# Out:
#    casual  temp  ...  time_of_day_midday  time_of_day_morning_commute
# 0       3  9.84  ...                   0                            0
# 1       8  9.02  ...                   0                            0
# 2       5  9.02  ...                   0                            0
# 3       3  9.84  ...                   0                            0
# 4       0  9.84  ...                   0                            0
#
# [5 rows x 13 columns]

# %%
bikes.head()
# Out:
#              datetime  season  holiday  ...  hour  time_of_day  weekday
# 0 2011-01-01 00:00:00       1        0  ...     0   afterhours        5
# 1 2011-01-01 01:00:00       1        0  ...     1   afterhours        5
# 2 2011-01-01 02:00:00       1        0  ...     2   afterhours        5
# 3 2011-01-01 03:00:00       1        0  ...     3   afterhours        5
# 4 2011-01-01 04:00:00       1        0  ...     4   afterhours        5
#
# [5 rows x 15 columns]

# %%
model_data.columns
# Out:
# Index(['casual', 'temp', 'weekday_0', 'weekday_1', 'weekday_2', 'weekday_3',
#        'weekday_4', 'weekday_5', 'weekday_6', 'time_of_day_afterhours',
#        'time_of_day_evening_commute', 'time_of_day_midday',
#        'time_of_day_morning_commute'],
#       dtype='object')

# %%
model = ols("casual ~ temp +  weekday_1 + weekday_2 + weekday_3 + \
       weekday_4 + weekday_5 + weekday_6  + \
            time_of_day_evening_commute + time_of_day_midday + time_of_day_morning_commute", data=model_data).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 casual   R-squared:                       0.510
# Model:                            OLS   Adj. R-squared:                  0.510
# Method:                 Least Squares   F-statistic:                     1134.
# Date:                Wed, 26 Jun 2024   Prob (F-statistic):               0.00
# Time:                        21:04:40   Log-Likelihood:                -54136.
# No. Observations:               10886   AIC:                         1.083e+05
# Df Residuals:                   10875   BIC:                         1.084e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                     -41.3638      1.297    -31.892      0.000     -43.906     -38.821
# temp                            2.4854      0.044     56.343      0.000       2.399       2.572
# weekday_1                      -7.2233      1.258     -5.741      0.000      -9.690      -4.757
# weekday_2                      -6.5839      1.256     -5.242      0.000      -9.046      -4.122
# weekday_3                      -4.8948      1.256     -3.899      0.000      -7.356      -2.434
# weekday_4                       2.7415      1.261      2.175      0.030       0.270       5.213
# weekday_5                      36.2621      1.250     29.011      0.000      33.812      38.712
# weekday_6                      28.6977      1.250     22.949      0.000      26.246      31.149
# time_of_day_evening_commute    44.0383      0.981     44.884      0.000      42.115      45.962
# time_of_day_midday             46.2159      0.859     53.830      0.000      44.533      47.899
# time_of_day_morning_commute     5.6867      0.972      5.852      0.000       3.782       7.592
# ==============================================================================
# Omnibus:                     4902.799   Durbin-Watson:                   0.295
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            38301.131
# Skew:                           1.994   Prob(JB):                         0.00
# Kurtosis:                      11.279   Cond. No.                         163.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model_data.head()
# Out:
#    casual  temp  ...  time_of_day_midday  time_of_day_morning_commute
# 0       3  9.84  ...                   0                            0
# 1       8  9.02  ...                   0                            0
# 2       5  9.02  ...                   0                            0
# 3       3  9.84  ...                   0                            0
# 4       0  9.84  ...                   0                            0
#
# [5 rows x 13 columns]

# %%
predictions = model.predict(model_data.iloc[:,1:])

# %%
model.params
# Out:
# Intercept                     -41.363774
# temp                            2.485440
# weekday_1                      -7.223317
# weekday_2                      -6.583888
# weekday_3                      -4.894790
# weekday_4                       2.741512
# weekday_5                      36.262129
# weekday_6                      28.697654
# time_of_day_evening_commute    44.038322
# time_of_day_midday             46.215897
# time_of_day_morning_commute     5.686747
# dtype: float64

# %%
model_data.head()
# Out:
#    casual  temp  ...  time_of_day_midday  time_of_day_morning_commute
# 0       3  9.84  ...                   0                            0
# 1       8  9.02  ...                   0                            0
# 2       5  9.02  ...                   0                            0
# 3       3  9.84  ...                   0                            0
# 4       0  9.84  ...                   0                            0
#
# [5 rows x 13 columns]

# %%
final_data = pd.concat([model_data, predictions], axis=1)

# %%
final_data.rename(columns={0:'predictions'}, inplace=True)

# %%
final_data['residuals'] = final_data['predictions'] - final_data['casual']

# %%
# predicted vs residuals

sns.scatterplot(x='predictions', y='residuals', data=final_data)
# Out:
# <AxesSubplot: xlabel='predictions', ylabel='residuals'>

# %%
# check for normal distribution of residuals
sns.histplot(final_data['residuals'])
# Out:
# <AxesSubplot: xlabel='residuals', ylabel='Count'>

# %%
import statsmodels.api as sm

# %%
sm.graphics.influence_plot(model, criterion = 'cooks')

# %%
np.mean(np.sqrt(final_data['residuals']**2))
# Out:
# 24.37005700126345

# %%
np.mean(final_data.casual)
# Out:
# 36.02195480433584

# %%
24/36
# Out:
# 0.6666666666666666
